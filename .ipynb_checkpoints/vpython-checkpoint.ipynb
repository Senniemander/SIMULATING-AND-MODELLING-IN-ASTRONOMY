# %%
from vpython import *
from __future__ import division, print_function
from math import *

# %%
# from vpython import *
box()

# %%
from __future__ import division, print_function
from math import *
from vpython import *
scene = canvas() # This is needed in Jupyter notebook and lab to make programs easily rerunnable
G = 6.7e-11
scene.forward = vec(0,-.3,-1)

giant = sphere(pos=vector(-1e11,0,0), radius=2e10, color=color.red, 
                make_trail=True, trail_type='points', interval=10, retain=20)
giant.mass = 2e30
giant.p = vector(0, 0, -1e4) * giant.mass

dwarf = sphere(pos=vector(1.5e11,0,0), radius=1e10, color=color.yellow,
                make_trail=True, retain=40)
dwarf.mass = 1e30
dwarf.p = -giant.p

dt = 1e5
while True:
    rate(200)
    r = dwarf.pos - giant.pos
    F = G * giant.mass * dwarf.mass * norm(r) / mag2(r)
    giant.p = giant.p + F*dt
    dwarf.p = dwarf.p - F*dt
    giant.pos = giant.pos + (giant.p/giant.mass) * dt
    dwarf.pos = dwarf.pos + (dwarf.p/dwarf.mass) * dt
# Out:
# <div id="glowscript" class="glowscript"></div>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 8
#       5 G = 6.7e-11
#       6 scene.forward = vec(0,-.3,-1)
# ----> 8 giant = sphere(pos=vector(-1e11,0,0), radius=2e10, color=color.red,
#       9                 make_trail=True, trail_type='points', interval=10, retain=20)
#      10 giant.mass = 2e30
#      11 giant.p = vector(0, 0, -1e4) * giant.mass
#
# File ~/miniforge3/envs/amuse/lib/python3.12/site-packages/vpython/vpython.py:1189, in sphere.__init__(self, **args)
#    1187 args['_default_size'] = vector(2,2,2)
#    1188 args['_objName'] = "sphere"
# -> 1189 super(sphere, self).setup(args)
#    1190 self._sizing = False
#
# File ~/miniforge3/envs/amuse/lib/python3.12/site-packages/vpython/vpython.py:612, in standardAttributes.setup(self, args)
#     611 def setup(self, args):
# --> 612     super(standardAttributes, self).__init__()
#     613     self._constructing = True  ## calls to setters are from constructor
#     615     objName = self._objName = args['_objName']  ## identifies object type
#
# File ~/miniforge3/envs/amuse/lib/python3.12/site-packages/vpython/vpython.py:265, in baseObj.__init__(self, **kwargs)
#     262 if not (baseObj._view_constructed or
#     263         baseObj._canvas_constructing):
#     264     if _isnotebook:
# --> 265         from .with_notebook import _
#     266     else:
#     267         from .no_notebook import _
#
# File ~/miniforge3/envs/amuse/lib/python3.12/site-packages/vpython/with_notebook.py:71
#      66         except PermissionError:
#      67             #logging.info("PermissionError: Unable to install /vpython_data directory and files for VPython on JupyterLab")
#      68             pass
# ---> 71 if ('nbextensions' in os.listdir(jd)) and (notebook.__version__ <= '6.5.5'):
#      72     ldir = os.listdir(nbdir)
#      73     if ('vpython_data' in ldir and len(os.listdir(nbdata)) == datacnt and
#      74        'vpython_libraries' in ldir and len(os.listdir(nblib)) == libcnt and
#      75         'vpython_version.txt' in ldir):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/snrts/.local/share/jupyter'

# %%
scene = display(width=1500, height=600)
scene.append_to_caption(" B-field Strength = ")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 scene = display(width=1500, height=600)
# ----> 2 scene.append_to_caption(" B-field Strength = ")
#
# AttributeError: 'NoneType' object has no attribute 'append_to_caption'
